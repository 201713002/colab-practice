# %% [markdown]
# <a href="https://colab.research.google.com/github/201713002/colab-practice/blob/master/%EC%84%A0%ED%98%95%ED%9A%8C%EA%B7%80.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from matplotlib import pyplot as plt
from sklearn.datasets import load_diabetes
diabetes = load_diabetes()

# print(np.__version__)
# print(diabetes.data.shape, diabetes.target.shape)

x = diabetes.data[:, 2]
y = diabetes.target

w = 1.0
b = 1.0
for i in range(1,100):
  for x_i, y_i in zip(x,y):
    y_hat = x_i * w + b
    err = y_i - y_hat
    w_rate = x_i
    w += w_rate * err
    b += 1 * err
print(w,b)

plt.scatter(x,y)
# 경사하강법에 의한 그래프
pt1 = (-0.1, -0.1*w + b)
pt2 = (0.15, 0.15*w + b)
plt.plot([pt1[0], pt2[0]], [pt1[1], pt2[1]])
plt.scatter(x_new, y_pred)
# 경사하강법에 의한 x_new에 대한 예측값
x_new = 0.18
y_pred = x_new * w + b  # 288

# 회귀분석에 의한 가중치와 절편
w_r = 949.43526
b_r = 152.133484
# 회귀분석에 의한 그래프
pt3 = (-0.1, -0.1*w_r + b_r)
pt4 = (0.15, 0.15*w_r + b_r)
plt.plot([pt3[0], pt4[0]], [pt3[1], pt4[1]])
plt.scatter(x_new, y_pred_r)
# 회귀분석에 의한 x_new에 대한 예측값
y_pred_r = x_new * w_r + b_r  # 323

plt.xlabel('x')
plt.ylabel('y')
plt.title("Linear Regression")
plt.show()
# Out:
# 913.5973364345905 123.39414383177204

# %%
import numpy as np
from matplotlib import pyplot as plt
from sklearn.datasets import load_diabetes
diabetes = load_diabetes()

class Neuron:

  def __init__(self):
    self.w = 1.0
    self.b = 1.0

  def forpass(self, x):
    y_hat = x * self.w + self.b
    return y_hat

  def backprop(self, x, err):
    w_grad = x * err
    b_grad = 1 * err
    return w_grad, b_grad

  def fit(self, x, y, epochs=100):
    for i in range(epochs):
      for x_i, y_i in zip(x,y):
        y_hat = self.forpass(x_i)
        err = -(y_i - y_hat)
        w_grad, b_grad = self.backprop(x_i, err)
        self.w -= w_grad
        self.b -= b_grad

neuron = Neuron()
x = diabetes.data[:, 2]
y = diabetes.target
neuron.fit(x,y)
print(neuron.w, neuron.b)

x_new = 0.18
y_pred = x_new * neuron.w + neuron.b

plt.scatter(x,y)
plt.scatter(x_new, y_pred)
pt1 = (-0.1, -0.1*neuron.w + neuron.b)
pt2 = (0.15, 0.15*neuron.w + neuron.b)
plt.plot([pt1[0], pt2[0]], [pt1[1], pt2[1]])
plt.xlabel('x')
plt.ylabel('y')
plt.title("Linear Regression")
plt.show()
# Out:
# 913.5973364345905 123.39414383177204

# %%
from sklearn.datasets import load_diabetes
diabetes = load_diabetes()
x = diabetes.data[:, 2]
y = diabetes.target

# str_x_l = list(map(str, x))
# str_x = ",".join(str_x_l)
# with open("diabetes_x2.csv","w") as f:
#   f.write(str_x)
str_y_l = list(map(str, y))
str_y = ",".join(str_y_l)
with open("diabetes_y.csv","w") as f:
  f.write(str_y)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
